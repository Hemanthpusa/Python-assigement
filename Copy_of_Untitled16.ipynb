# %% [markdown]
# <a href="https://colab.research.google.com/github/Hemanthpusa/Python-assigement/blob/main/Copy_of_Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math as m

# %%
data=pd.read_csv("auto-mpg.csv1.csv",
                 names=["mpg","cylinders","displacement","horsepower","weight","acceleration","model year","origin","car names"])

# %%
data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0         130    3504          12.0
# 1    15.0          8         350.0         165    3693          11.5
# 2    18.0          8         318.0         150    3436          11.0
# 3    16.0          8         304.0         150    3433          12.0
# 4    17.0          8         302.0         140    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0          86    2790          15.6
# 394  44.0          4          97.0          52    2130          24.6
# 395  32.0          4         135.0          84    2295          11.6
# 396  28.0          4         120.0          79    2625          18.6
# 397  31.0          4         119.0          82    2720          19.4
#
#      model year  origin                  car names
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
data.tail(40)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 358  31.6          4         120.0          74    2635          18.3
# 359  28.1          4         141.0          80    3230          20.4
# 360  30.7          6         145.0          76    3160          19.6
# 361  25.4          6         168.0         116    2900          12.6
# 362  24.2          6         146.0         120    2930          13.8
# 363  22.4          6         231.0         110    3415          15.8
# 364  26.6          8         350.0         105    3725          19.0
# 365  20.2          6         200.0          88    3060          17.1
# 366  17.6          6         225.0          85    3465          16.6
# 367  28.0          4         112.0          88    2605          19.6
# 368  27.0          4         112.0          88    2640          18.6
# 369  34.0          4         112.0          88    2395          18.0
# 370  31.0          4         112.0          85    2575          16.2
# ...

# %%
data.horsepower.mean()
# Out:
# 102.89447236180905

# %%
data['horsepower']=data['horsepower'].replace(0,data['horsepower'].mean())

# %%
data.tail(50)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 348  37.7          4          89.0   62.000000    2050          17.3
# 349  34.1          4          91.0   68.000000    1985          16.0
# 350  34.7          4         105.0   63.000000    2215          14.9
# 351  34.4          4          98.0   65.000000    2045          16.2
# 352  29.9          4          98.0   65.000000    2380          20.7
# 353  33.0          4         105.0   74.000000    2190          14.2
# 354  34.5          4         100.0  102.894472    2320          15.8
# 355  33.7          4         107.0   75.000000    2210          14.4
# 356  32.4          4         108.0   75.000000    2350          16.8
# 357  32.9          4         119.0  100.000000    2615          14.8
# 358  31.6          4         120.0   74.000000    2635          18.3
# 359  28.1          4         141.0   80.000000    3230          20.4
# 360  30.7          6         145.0   76.000000    3160          19.6
# ...

# %%
data.head(50)
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0   18.0          8         307.0  130.000000    3504          12.0
# 1   15.0          8         350.0  165.000000    3693          11.5
# 2   18.0          8         318.0  150.000000    3436          11.0
# 3   16.0          8         304.0  150.000000    3433          12.0
# 4   17.0          8         302.0  140.000000    3449          10.5
# 5   15.0          8         429.0  198.000000    4341          10.0
# 6   14.0          8         454.0  220.000000    4354           9.0
# 7   14.0          8         440.0  215.000000    4312           8.5
# 8   14.0          8         455.0  225.000000    4425          10.0
# 9   15.0          8         390.0  190.000000    3850           8.5
# 10  15.0          8         383.0  170.000000    3563          10.0
# 11  14.0          8         340.0  160.000000    3609           8.0
# 12  15.0          8         400.0  150.000000    3761           9.5
# ...

# %%
plt.scatter(data['cylinders'],data['mpg'])
plt.xlabel('cylinders')
plt.ylabel('mpg')
plt.show()

# %%
plt.scatter(data['horsepower'],data['mpg'])
plt.xlabel('horsepower')
plt.ylabel('mpg')
plt.show()

# %%
plt.scatter(data['weight'],data['mpg'])
plt.xlabel('weight')
plt.ylabel('mpg')
plt.show()

# %%
plt.scatter(data['model year'],data['mpg'])
plt.xlabel('model year')
plt.ylabel('mpg')
plt.show()

# %%
sns.pairplot(data,size=1.5)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.heatmap(data.corr(),annot=True,linewidth=0.2)

# %% [markdown]
# Fitting Linear Regression:

# %%
x=data.drop(['mpg','car names'],axis=1)

# %%
y=data["mpg"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.3,random_state=10)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_test
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model year  \
# 331          4          97.0        67.0    2145          18.0          80
# 111          3          70.0        90.0    2124          13.5          73
# 350          4         105.0        63.0    2215          14.9          81
# 205          4          97.0        75.0    2155          16.4          76
# 56           4          91.0        70.0    1955          20.5          71
# ..         ...           ...         ...     ...           ...         ...
# 17           6         200.0        85.0    2587          16.0          70
# 225          6         250.0       110.0    3520          16.4          77
# 223          8         318.0       145.0    4140          13.7          77
# 59           4          97.0        54.0    2254          23.5          72
# 114          4          98.0        90.0    2265          15.5          73
#
#      origin
# 331       3
# 111       3
# 350       1
# 205       3
# ...

# %%
predictions=lm.predict(x_test)

# %%
predictions
# Out:
# array([33.97152566, 27.86987225, 30.98792742, 30.60878511, 25.71816879,
#        36.41789366, 26.55599772, 17.36176804, 28.50579444, 26.82377928,
#        23.76079855, 27.79792489, 36.21125749, 25.66913493, 20.61591698,
#        25.96902403, 21.28953877, 13.11978043,  8.89724189, 29.55724534,
#        18.05043862, 10.21114345, 35.36429073, 23.54119305, 26.9130542 ,
#        22.57720659, 26.30452957, 23.43223425, 29.82801047, 29.51463319,
#        14.16920436, 10.78146798, 29.0292968 ,  8.43027385, 33.54373247,
#        27.43693238, 35.22115609, 16.66388722, 21.27194871, 11.73315619,
#        28.32303471, 31.93716505, 14.98845706, 17.66600158, 31.02833586,
#        31.50168216, 21.53041721, 15.83989254, 29.20713586, 14.83984658,
#        20.15616235, 21.22844964, 26.40149748, 19.95441659, 34.7166908 ,
#        32.39393563, 22.66456924, 13.80327651, 31.34086714, 27.37262431,
#        24.50753394, 24.96506223, 35.26248482, 16.7375394 , 32.7647713 ,
# ...

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
r2_score(y_test,predictions)
# Out:
# 0.8252904052876381

# %%
MSE=mean_squared_error(y_test,predictions,squared=True)
MSE
# Out:
# 10.06647372345072

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 2.4875318756341898

# %%
RMSE=np.sqrt(MSE)
RMSE
# Out:
# 3.1727706698484717
